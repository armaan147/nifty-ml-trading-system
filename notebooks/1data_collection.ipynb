# %%
import yfinance as yf
import pandas as pd
print("SUCCESS: yfinance working")
# Out:
# SUCCESS: yfinance working

# %%
import yfinance as yf
import pandas as pd

data = yf.download("^NSEI", interval="5m", period="60d")

data.reset_index(inplace=True)
data.to_csv("../data/nifty_spot_5min.csv", index=False)

data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                   Datetime         Close          High           Low  \
# Ticker                                   ^NSEI         ^NSEI         ^NSEI
# 0      2025-10-27 03:45:00+00:00  25861.400391  25877.599609  25828.099609
# 1      2025-10-27 03:50:00+00:00  25880.949219  25882.900391  25862.849609
# 2      2025-10-27 03:55:00+00:00  25889.050781  25891.000000  25867.250000
# 3      2025-10-27 04:00:00+00:00  25896.550781  25899.250000  25880.949219
# 4      2025-10-27 04:05:00+00:00  25921.500000  25927.000000  25895.949219
#
# Price           Open Volume
# Ticker         ^NSEI  ^NSEI
# 0       25851.949219      0
# 1       25862.849609      0
# 2       25880.099609      0
# 3       25889.150391      0
# 4       25897.050781      0
